# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_excel('../results/xlsx_file/Analysis_B1.xlsx')

# %%
df_train.head()
# Out:
#    Unnamed: 0      Lot Wafer      Mask  TestSite                  Name  \
# 0           0  P184640   D07  GORILLA5  DCM_LMZC  MZMCTE_LULAB_450_500
# 1           1  P184640   D07  GORILLA5  DCM_LMZC  MZMCTE_LULAB_450_500
# 2           2  P184640   D07  GORILLA5  DCM_LMZC  MZMCTE_LULAB_450_500
# 3           3  P184640   D07  GORILLA5  DCM_LMZC  MZMCTE_LULAB_450_500
# 4           4  P184640   D07  GORILLA5  DCM_LMZC  MZMCTE_LULAB_450_500
#
#               Date     Scrip ID  Script Version Script Owner  ... Column  \
# 0  20190715_191538  process LMZ             0.1           B1  ...     -1
# 1  20190715_192145  process LMZ             0.1           B1  ...     -3
# 2  20190715_202217  process LMZ             0.1           B1  ...      3
# 3  20190715_195142  process LMZ             0.1           B1  ...     -3
# 4  20190715_193943  process LMZ             0.1           B1  ...      0
#
#    ErrorFlag  Error description  Analysis Wavelength Rsq of Ref.spectrum(6th)  \
# ...

# %%
sns.swarmplot(x = 'Wafer', y = 'ErrorFlag', data = df_train)
plt.title('ErrorFlag-swarm')
# Out:
# Text(0.5, 1.0, 'ErrorFlag-swarm')

# %%
sns.boxplot(x = 'Wafer', y = 'ErrorFlag', data = df_train)
plt.title('ErrorFlag-box')
# Out:
# Text(0.5, 1.0, 'ErrorFlag-box')

# %%
sns.swarmplot(x = 'Wafer', y = 'Analysis Wavelength', data = df_train)
plt.title('Analysis Wavelength - swarm')
# Out:
# Text(0.5, 1.0, 'Analysis Wavelength - swarm')

# %%
sns.boxplot(x = 'Wafer', y = 'Analysis Wavelength', data = df_train)
plt.title('Analysis Wavelength - box')
# Out:
# Text(0.5, 1.0, 'Analysis Wavelength - box')

# %%
sns.swarmplot(x = 'Wafer', y = 'Max transmission of Ref spec(dB)', data = df_train)
plt.title('Max transmission of Ref spec(dB) - swarm')
# Out:
# Text(0.5, 1.0, 'Max transmission of Ref spec(dB) - swarm')

# %%
sns.boxplot(x = 'Wafer', y = 'Max transmission of Ref spec(dB)', data = df_train)
plt.title('Max transmission of Ref spec(dB) - box')
# Out:
# Text(0.5, 1.0, 'Max transmission of Ref spec(dB) - box')

# %%
sns.swarmplot(x = 'Wafer', y = 'I at -1V[A]', data = df_train)
plt.title('I at -1V[A] - swarm')
# Out:
# Text(0.5, 1.0, 'I at -1V[A] - swarm')

# %%
sns.boxplot(x = 'Wafer', y = 'I at -1V[A]', data = df_train)
plt.title('I at -1V[A] - box')
# Out:
# Text(0.5, 1.0, 'I at -1V[A] - box')

# %%
sns.swarmplot(x = 'Wafer', y = 'I at 1V[A]', data = df_train)
plt.title('I at 1V[A] - swarm')
# Out:
# Text(0.5, 1.0, 'I at 1V[A] - swarm')

# %%
sns.boxplot(x = 'Wafer', y = 'I at 1V[A]', data = df_train)
plt.title('I at 1V[A] - box')
# Out:
# Text(0.5, 1.0, 'I at 1V[A] - box')

# %%
sns.swarmplot(x = 'Wafer', y = 'Rsq of Ref.spectrum(6th)', data = df_train)
plt.title('Rsq of Ref.spectrum(6th) - swarm')
# Out:
# Text(0.5, 1.0, 'Rsq of Ref.spectrum(6th) - swarm')

# %%
sns.boxplot(x = 'Wafer', y = 'Rsq of Ref.spectrum(6th)', data = df_train)
plt.title('Rsq of Ref.spectrum(6th) - box')
# Out:
# Text(0.5, 1.0, 'Rsq of Ref.spectrum(6th) - box')
